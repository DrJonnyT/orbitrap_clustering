# %% [markdown]
# Loader for York Orbitrap tracer data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_beijing_mz = pd.read_excel(r"C:\Users\mbcx5jt5\Google Drive\Shared_York_MAn2\Beijing_Amb3.1_MZ.xlsx",engine='openpyxl')

# %%
df_beijing_mz.head()
# Out:
#    Checked        m/z Annotation Source: Predicted Compositions  \
# 0     True  274.00296                                Full match
# 1     True  274.00290                                Full match
# 2     True  226.03580                                Full match
# 3     True  210.04111                                Full match
# 4     True  210.04100                                Full match
#
#   Annotation Source: mzCloud Search Annotation Source: mzVault Search  \
# 0                        No results                        No results
# 1                        No results                        No results
# 2                        No results                        No results
# 3                        No results                        No results
# 4                        No results                        No results
#
#   Annotation Source: ChemSpider Search Annotation Source: MassList Search  \
# 0                             No match                         No results
# ...

# %%
df_beijing_mz.shape
# Out:
# (1875, 194)

# %%
#Make a dataframe with the different filters, indexed by the different peaks
#colnames_mzfilters = [df_beijing_mz.columns.tolist()[1] , df_beijing_mz.columns.tolist()[18:]]
df_beijing_filters = df_beijing_mz.iloc[:,list(range(18,194))]
df_beijing_filters.head()
# Out:
#    Area: 13-02-19_Beijing_128.raw (F1)  Area: 13-02-19_Beijing_129.raw (F2)  \
# 0                         6.928940e+04                         3.785278e+06
# 1                         1.810833e+05                         1.637947e+07
# 2                         2.750764e+05                         1.300307e+06
# 3                         1.518004e+06                         2.149736e+06
# 4                         8.500570e+05                         1.373919e+06
#
#    Area: 13-02-19_Beijing_130.raw (F3)  Area: 13-02-19_Beijing_131.raw (F4)  \
# 0                         2.237998e+05                         1.254915e+05
# 1                         6.714690e+05                         2.508359e+05
# 2                         4.246526e+05                         2.719411e+05
# 3                         3.010492e+06                         2.811780e+06
# 4                         2.036762e+06                         3.075917e+06
#
# ...

# %%
#Add in a unique identifier for each peak as the row in the excel file
df_excel_row = pd.DataFrame(range(2,1877),columns=['excel_row'])

#Ignore the error it's a false positive (I think...)
df_beijing_filters['excel_row'] = range(2,1877)
df_beijing_filters.set_index('excel_row')
# Out:
# C:\Users\mbcx5jt5\Anaconda3\envs\keras_gpu\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#            Area: 13-02-19_Beijing_128.raw (F1)  \
# excel_row
# 2                                 6.928940e+04
# 3                                 1.810833e+05
# 4                                 2.750764e+05
# 5                                 1.518004e+06
# 6                                 8.500570e+05
# ...                                        ...
# 1872                              1.309391e+05
# 1873                              2.142336e+05
# 1874                              1.213779e+05
# 1875                              3.003598e+05
# 1876                              2.900829e+06
#
# ...

# %%
df_beijing_filters = df_beijing_filters.transpose()

# %%
df_beijing_filters.head()
# Out:
#                                              0             1             2     \
# Area: 13-02-19_Beijing_128.raw (F1)  6.928940e+04  1.810833e+05  2.750764e+05
# Area: 13-02-19_Beijing_129.raw (F2)  3.785278e+06  1.637947e+07  1.300307e+06
# Area: 13-02-19_Beijing_130.raw (F3)  2.237998e+05  6.714690e+05  4.246526e+05
# Area: 13-02-19_Beijing_131.raw (F4)  1.254915e+05  2.508359e+05  2.719411e+05
# Area: 13-02-19_Beijing_132.raw (F5)  7.731047e+04  2.040614e+05  1.073316e+05
#
#                                              3             4             5     \
# Area: 13-02-19_Beijing_128.raw (F1)  1.518004e+06  8.500570e+05  1.622223e+06
# Area: 13-02-19_Beijing_129.raw (F2)  2.149736e+06  1.373919e+06  3.324936e+06
# Area: 13-02-19_Beijing_130.raw (F3)  3.010492e+06  2.036762e+06  1.695116e+06
# Area: 13-02-19_Beijing_131.raw (F4)  2.811780e+06  3.075917e+06  1.309109e+06
# Area: 13-02-19_Beijing_132.raw (F5)  1.221605e+06  5.210333e+05  1.309102e+06
#
# ...

# %%
plt.scatter(df_beijing_mz['m/z'],df_beijing_mz['RT [min]'])
